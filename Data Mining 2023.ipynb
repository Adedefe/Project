# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv(r'C:\\Users\\folak\\Downloads\\toyota.csv')
df
# Out:
#                model  year  price transmission  mileage fuelType  tax   mpg  \
# 0               GT86  2016  16000       Manual    24089   Petrol  265  36.2
# 1               GT86  2017  15995       Manual    18615   Petrol  145  36.2
# 2               GT86  2015  13998       Manual    27469   Petrol  265  36.2
# 3               GT86  2017  18998       Manual    14736   Petrol  150  36.2
# 4               GT86  2017  17498       Manual    36284   Petrol  145  36.2
# ...              ...   ...    ...          ...      ...      ...  ...   ...
# 6733              IQ  2011   5500    Automatic    30000   Petrol   20  58.9
# 6734   Urban Cruiser  2011   4985       Manual    36154   Petrol  125  50.4
# 6735   Urban Cruiser  2012   4995       Manual    46000   Diesel  125  57.6
# 6736   Urban Cruiser  2011   3995       Manual    60700   Petrol  125  50.4
# 6737   Urban Cruiser  2011   4495       Manual    45128   Petrol  125  50.4
#
#       engineSize
# 0            2.0
# 1            2.0
# ...

# %%
df['model'].value_counts()
# Out:
#  Yaris            2122
#  Aygo             1961
#  Auris             712
#  C-HR              479
#  RAV4              473
#  Corolla           267
#  Prius             232
#  Avensis           115
#  Verso             114
#  Hilux              86
#  GT86               73
#  Land Cruiser       51
#  PROACE VERSO       15
#  Supra              12
#  Camry              11
#  IQ                  8
#  Urban Cruiser       4
#  Verso-S             3
# Name: model, dtype: int64

# %%
df.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#    model transmission fuelType
# 0   GT86       Manual   Petrol
# 1   GT86       Manual   Petrol
# 2   GT86       Manual   Petrol
# 3   GT86       Manual   Petrol
# 4   GT86       Manual   Petrol

# %%
obj_df[obj_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [model, transmission, fuelType]
# Index: []

# %%
y = df['price']
x = df[['mileage','tax','mpg','engineSize']]

# %%
# define the multiple Linear regression model
linear_regress = LinearRegression()
linear_regress.fit(x,y)
# Out:
# LinearRegression()

# %%
# predict with the data
y_pred = linear_regress.predict(x)

# %%
y_pred
# Out:
# array([18185.7700879 , 18665.53052313, 17688.58196556, ...,
#         8182.65196892,  4606.846301  ,  6897.44199365])

# %%
import matplotlib.pyplot as plt
df['model'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
df=df.dropna()
df.isnull().any()
# Out:
# model           False
# year            False
# price           False
# transmission    False
# mileage         False
# fuelType        False
# tax             False
# mpg             False
# engineSize      False
# dtype: bool

# %%
df1=df.copy()
df.head()
# Out:
#    model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 1   GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2   GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# 3   GT86  2017  18998       Manual    14736   Petrol  150  36.2         2.0
# 4   GT86  2017  17498       Manual    36284   Petrol  145  36.2         2.0

# %%
df1["new_col"]=df1['model']
df1.head()
# Out:
#    model  year  price transmission  mileage fuelType  tax   mpg  engineSize  \
# 0   GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 1   GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2   GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# 3   GT86  2017  18998       Manual    14736   Petrol  150  36.2         2.0
# 4   GT86  2017  17498       Manual    36284   Petrol  145  36.2         2.0
#
#   new_col
# 0    GT86
# 1    GT86
# 2    GT86
# 3    GT86
# 4    GT86

# %%
df["model"].value_counts()
df.head()
# Out:
#    model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 1   GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2   GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# 3   GT86  2017  18998       Manual    14736   Petrol  150  36.2         2.0
# 4   GT86  2017  17498       Manual    36284   Petrol  145  36.2         2.0

# %%
df.shape
# Out:
# (6738, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6738 entries, 0 to 6737
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         6738 non-null   object
#  1   year          6738 non-null   int64
#  2   price         6738 non-null   int64
#  3   transmission  6738 non-null   object
#  4   mileage       6738 non-null   int64
#  5   fuelType      6738 non-null   object
#  6   tax           6738 non-null   int64
#  7   mpg           6738 non-null   float64
#  8   engineSize    6738 non-null   float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 526.4+ KB

# %%
df.describe()
# Out:
#               year         price        mileage          tax          mpg  \
# count  6738.000000   6738.000000    6738.000000  6738.000000  6738.000000
# mean   2016.748145  12522.391066   22857.413921    94.697240    63.042223
# std       2.204062   6345.017587   19125.464147    73.880776    15.836710
# min    1998.000000    850.000000       2.000000     0.000000     2.800000
# 25%    2016.000000   8290.000000    9446.000000     0.000000    55.400000
# 50%    2017.000000  10795.000000   18513.000000   135.000000    62.800000
# 75%    2018.000000  14995.000000   31063.750000   145.000000    69.000000
# max    2020.000000  59995.000000  174419.000000   565.000000   235.000000
#
#         engineSize
# count  6738.000000
# mean      1.471297
# std       0.436159
# min       0.000000
# 25%       1.000000
# 50%       1.500000
# 75%       1.800000
# max       4.500000

# %%
df.columns
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')

# %%
X=df1.iloc[:,:3].values
Y=df1.iloc[:,4].values
Y
# Out:
# array([24089, 18615, 27469, ..., 46000, 60700, 45128], dtype=int64)

# %%
df1.corr()
# Out:
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.420959 -0.727749  0.283455 -0.020607   -0.045567
# price       0.420959  1.000000 -0.297936  0.214498 -0.039910    0.727592
# mileage    -0.727749 -0.297936  1.000000 -0.205285  0.044889    0.182615
# tax         0.283455  0.214498 -0.205285  1.000000 -0.430292    0.155727
# mpg        -0.020607 -0.039910  0.044889 -0.430292  1.000000   -0.106868
# engineSize -0.045567  0.727592  0.182615  0.155727 -0.106868    1.000000

# %%
obj_df["model"] = obj_df["model"].astype('category')
obj_df.dtypes
# Out:
# model           category
# transmission      object
# fuelType          object
# dtype: object

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
scale=StandardScaler()
encode=LabelEncoder()

# %%
df1_encoder=df1.copy()

# %%
X_en=df1.copy()

# %%
X_en['price']=encode.fit_transform(X_en['mileage'])

# %%
X_en.head()
# Out:
#    model  year  price transmission  mileage fuelType  tax   mpg  engineSize  \
# 0   GT86  2016   3504       Manual    24089   Petrol  265  36.2         2.0
# 1   GT86  2017   2757       Manual    18615   Petrol  145  36.2         2.0
# 2   GT86  2015   3848       Manual    27469   Petrol  265  36.2         2.0
# 3   GT86  2017   2208       Manual    14736   Petrol  150  36.2         2.0
# 4   GT86  2017   4622       Manual    36284   Petrol  145  36.2         2.0
#
#   new_col
# 0    GT86
# 1    GT86
# 2    GT86
# 3    GT86
# 4    GT86

# %%
#normalization with the help of standard scaler
X_scale=scale.fit_transform

# %%
X_scale
# Out:
# <bound method TransformerMixin.fit_transform of StandardScaler()>

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df['model'],df['price'])
